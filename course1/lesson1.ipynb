# %% [markdown]
# # LECCION 1

# %% [markdown]
# # EJERCICIO 1: Crear 3 variables  con los datos de la imagen
# ejemplo:
#
# nombre = "march"
#
# edad = 23
#
#
# ![image.png](data:image/png;base64,...)

# %%
# ESTUDIANTE 2
nombre="Lisa"
print(nombre)
# Out:
# Lisa

# %%
# ESTUDIANTE 3
edad="15"

# %% [markdown]
# # EJERCICIO 2
#
# ![image.png](data:image/png;base64,...)

# %%
total = 2  #  multiplicar 11 veces

# %%
total = 5  # multiplicar 12 veces

# %% [markdown]
# # EJERCICIO 3
# ```
# def saludo(nombre):
#   print("hola "+ nombre)
# ```
#
# como llamo a la función?

# %%
def saludo(nombre):
  print("hola "+ nombre)
nombre="Maria"
saludo(nombre)
# Out:
# hola Maria

# %%
def decir_edad():
  print("hola "+ edad)

# %%
def decir_un_chiste(chiste):
  print("hola chiste")
